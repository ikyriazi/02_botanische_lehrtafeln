# %%
# Task: Find images in a single LIDO file (Collection: Botanische Lehrtafeln)

# %%
import lxml

# %%
from lxml import etree

# %%
tree2print = lxml.etree.parse("test-metadaten/record_naniweb_455421.xml")
pretty = lxml.etree.tostring(tree2print, encoding="unicode", pretty_print=True)
print(pretty)
# Out:
# <lido:lido xmlns:gml="http://www.opengis.net/gml" xmlns:lido="http://www.lido-schema.org" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.lido-schema.org http://www.lido-schema.org/schema/v1.0/lido-v1.0.xsd">
#    <lido:lidoRecID lido:type="http://terminology.lido-schema.org/identifier_type/local_identifier">record_naniweb_455421</lido:lidoRecID>
#    <lido:objectPublishedID lido:type="http://terminology.lido-schema.org/identifier_type/uri">http://sammlungen.uni-goettingen.de/objekt/record_naniweb_455421</lido:objectPublishedID>
#    <lido:objectPublishedID lido:type="http://terminology.lido-schema.org/identifier_type/uri">https://hdl.handle.net/21.11107/ec596b93-47ed-4883-8464-b3c8425e560c</lido:objectPublishedID>
#    <lido:category>
#       <lido:conceptID lido:type="http://terminology.lido-schema.org/identifier_type/uri">http://www.cidoc-crm.org/crm-concepts/#E22</lido:conceptID>
#       <lido:term xml:lang="en">Man-Made Object</lido:term>
# ...

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('test-metadaten/record_naniweb_455421.xml')
root = tree.getroot()

# %%
ns = {'lido':'http://www.lido-schema.org'}

# %%
root.tag
# Out:
# '{http://www.lido-schema.org}lido'

# %%
root.findall(".")
# Out:
# [<Element '{http://www.lido-schema.org}lido' at 0x105ae08b0>]

# %%
resourceSets = root.findall(".//lido:resourceSet", ns)
print(resourceSets)
# Out:
# [<Element '{http://www.lido-schema.org}resourceSet' at 0x105cfe220>, <Element '{http://www.lido-schema.org}resourceSet' at 0x105d01a90>]

# %%
# function for finding the nth occurence of a substring
# https://stackoverflow.com/questions/1883980/find-the-nth-occurrence-of-substring-in-a-string
def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start+len(needle))
        n -= 1
    return start

# %%
for resourceSet in resourceSets:
    resourseRepresentations = resourceSet.findall("./lido:resourceRepresentation[@{http://www.lido-schema.org}type='http://terminology.lido-schema.org/resourceRepresentation_type/preview_representation']", ns)
    for resourseRepresentation in resourseRepresentations:
        link = resourseRepresentation.find("./lido:linkResource", ns).text
        print(link)
        
        # get the position of the second 'naniweb' --> I will need it later for downloading the images
        naniweb2occurence = find_nth(link, 'naniweb', 2)
        print(naniweb2occurence)
# Out:
# https://sammlungen.uni-goettingen.de/rest/image/record_naniweb_455421/record_naniweb_455421_6740.jpg/full/300,/0/default.jpg
# 77
# https://sammlungen.uni-goettingen.de/rest/image/record_naniweb_455421/record_naniweb_455421_7975.jpg/full/300,/0/default.jpg
# 77
